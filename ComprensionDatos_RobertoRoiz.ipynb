# %% [markdown]
# # Actividad obtención de estadísticas descriptivas
# Roberto Roiz A01235036

# %%
import pandas as pd

# %%
import matplotlib.pyplot as ply

# %%
import seaborn as sns

# %%
datos=pd.read_csv('diabetes.csv')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
datos
datos.min(axis=0)
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
datos
datos.max(axis=0)
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
datos.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # Descripción de Datos

# %% [markdown]
# Pregnancies es una variable cuantitativa discreta
# Glucose es una variable cuantitativa continua
# BloodPressure es una variable cuantitativa continua
# SkinThickness es una variable cuantitativa continua
# Insulin es una variable cuantitativa continua
# BMI es una variable cuantitativa continua
# DiabetesPedigreeFunction es una variable cuantitativa continua
# Age es una variable cuantitativa discreta
# Outcome es una variable cualitativa nominal

# %% [markdown]
# # Exploración de Datos

# %%
ax = sns.boxplot(x="Outcome", y="Pregnancies", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="Pregnancies",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
mean_pregnancies = datos['Pregnancies'].mean()
median_pregnancies =datos['Pregnancies'].median()
mode_pregnancies = datos['Pregnancies'].mode()
print("Mean_Pregnancies:",mean_pregnancies)
print("Median_Pregnancies:",median_pregnancies)
print("Mode_Pregnancies:",mode_pregnancies)
# Out:
# Mean_Pregnancies: 3.8450520833333335
# Median_Pregnancies: 3.0
# Mode_Pregnancies: 0    1
# dtype: int64

# %%
ax = sns.boxplot(x="Outcome", y="Glucose", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="Glucose",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
mean_glucose = datos['Glucose'].mean()
median_glucose =datos['Glucose'].median()
mode_glucose = datos['Glucose'].mode()
print("Mean_Glucose:",mean_glucose)
print("Median_Glucose:",median_glucose)
print("Mode_Glucose:",mode_glucose)
# Out:
# Mean_Glucose: 120.89453125
# Median_Glucose: 117.0
# Mode_Glucose: 0     99
# 1    100
# dtype: int64

# %%
ax = sns.boxplot(x="Outcome", y="BloodPressure", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="BloodPressure",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
mean_BloodPressure = datos['BloodPressure'].mean()
median_BloodPressure =datos['BloodPressure'].median()
mode_BloodPressure = datos['BloodPressure'].mode()
print("Mean_BloodPressure:",mean_BloodPressure)
print("Median_BloodPressure:",median_BloodPressure)
print("Mode_BloodPressure:",mode_BloodPressure)
# Out:
# Mean_BloodPressure: 69.10546875
# Median_BloodPressure: 72.0
# Mode_BloodPressure: 0    70
# dtype: int64

# %%
ax = sns.boxplot(x="Outcome", y="SkinThickness", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="SkinThickness",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
mean_SkinThickness = datos['SkinThickness'].mean()
median_SkinThickness =datos['SkinThickness'].median()
mode_SkinThickness = datos['SkinThickness'].mode()
print("Mean_SkinThickness:",mean_SkinThickness)
print("Median_SkinThickness:",median_SkinThickness)
print("Mode_SkinThickness:",mode_SkinThickness)
# Out:
# Mean_SkinThickness: 20.536458333333332
# Median_SkinThickness: 23.0
# Mode_SkinThickness: 0    0
# dtype: int64

# %%
ax = sns.boxplot(x="Outcome", y="Insulin", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="Insulin",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
mean_Insulin = datos['Insulin'].mean()
median_Insulin =datos['Insulin'].median()
mode_Insulin = datos['Insulin'].mode()
print("Mean_Insulin:",mean_Insulin)
print("Median_Insulin:",median_Insulin)
print("Mode_Insulin:",mode_Insulin)
# Out:
# Mean_Insulin: 79.79947916666667
# Median_Insulin: 30.5
# Mode_Insulin: 0    0
# dtype: int64

# %%
ax = sns.boxplot(x="Outcome", y="BMI", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="BMI",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
mean_BMI = datos['BMI'].mean()
median_BMI =datos['BMI'].median()
mode_BMI = datos['BMI'].mode()
print("Mean_BMI:",mean_BMI)
print("Median_BMI:",median_BMI)
print("Mode_BMI:",mode_BMI)
# Out:
# Mean_BMI: 31.992578124999977
# Median_BMI: 32.0
# Mode_BMI: 0    32.0
# dtype: float64

# %%
ax = sns.boxplot(x="Outcome", y="Age", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="Age",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
mean_Age = datos['Age'].mean()
median_Age =datos['Age'].median()
mode_Age = datos['Age'].mode()
print("Mean_Age:",mean_Age)
print("Median_Age:",median_Age)
print("Mode_Age:",mode_Age)
# Out:
# Mean_Age: 33.240885416666664
# Median_Age: 29.0
# Mode_Age: 0    22
# dtype: int64

# %%
datos.hist(bins=10,figsize=(9,7),grid=False);

# %%
correlation_matrix = datos.corr().round(2)

# %%
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt       
fig = plt.figure(figsize=(18,6))      

datos.Outcome.value_counts().plot(kind="bar",alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
datos.Pregnancies.value_counts(normalize=True).plot(kind="bar", alpha = 0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Preguntas
# ¿Hay alguna variable que no aporta información? BloodPressrure y SkinThickness tienen una correlación muy baja con Outcome.
#
# Si tuvieras que eliminar variables, ¿cuáles quitarías y por qué? Eliminaría las dos variables mencionadas en la priemr pregunta ya que no aportan información relevante para el estudio.
#
# ¿Existen variables que tengan datos extraños? Si, todas las variables tienen por lo menos 1 dato atípico.
#
# Si comparas las variables, ¿todas están en rangos similares? ¿Crees que esto afecte? Los rangos si son diferentes, si afecta ya que al ser rangos diferentes y con datos atípicos, el análisis resulta alterado.
#
# ¿Puedes encontrar grupos qué se parezcan? ¿Qué grupos son estos? Los grupos más parecidos en cuanto a rango y media son Age y BMI.
